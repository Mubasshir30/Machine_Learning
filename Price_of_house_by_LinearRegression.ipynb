# %% [markdown]
# Gathering the data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/Housing (1).csv")

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# Cleaning the data

# %%
data['mainroad']=data['mainroad'].apply({'yes':1,'no':0}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad guestroom basement  \
# 0  13300000  7420         4          2        3         1        no       no
# 1  12250000  8960         4          4        4         1        no       no
# 2  12250000  9960         3          2        2         1        no      yes
# 3  12215000  7500         4          2        2         1        no      yes
# 4  11410000  7420         4          1        2         1       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data['guestroom']=data['guestroom'].apply({'yes':1,'no':0}.get)

# %%
data['basement']=data['basement'].apply({'yes':1,'no':0}.get)

# %%
data['hotwaterheating']=data['hotwaterheating'].apply({'yes':1,'no':0}.get)

# %%
data['airconditioning']=data['airconditioning'].apply({'yes':1,'no':0}.get)

# %%
data['prefarea']=data['prefarea'].apply({'yes':1,'no':0}.get)

# %%
data['furnishingstatus']=data['furnishingstatus'].apply({'furnished':2,'unfurnished':0,'semi-furnished':1}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 2
# 1                 2
# 2                 1
# 3                 2
# 4                 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    int64
#  6   guestroom         545 non-null    int64
#  7   basement          545 non-null    int64
#  8   hotwaterheating   545 non-null    int64
#  9   airconditioning   545 non-null    int64
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    int64
#  12  furnishingstatus  545 non-null    int64
# dtypes: int64(13)
# memory usage: 55.5 KB

# %%
ax=data.plot(figsize=(10,15),title='Housing')
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
ax=data.iloc[1].plot(figsize=(10,15),title='housing')
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
ax=data.iloc[0:2].plot(figsize=(10,15),title='housing')
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
data.plot.scatter(x='area',y='price',c='stories')

# %%
data.plot.scatter(x='area',y='price')

# %%
sns.catplot(data=data,x='stories',y='price')
sns.catplot(data=data,x='stories',y='price',kind='box')
sns.catplot(data=data,x='stories',y='price',kind='violin')

# %%
data.plot.scatter(x='stories',y='price')

# %%
data.plot.scatter(x='bathrooms',y='price')

# %%
sns.catplot(data=data,x='bathrooms',y='price',kind='box')

# %%
sns.catplot(data=data,x='bathrooms',y='price',kind='violin')
sns.catplot(data=data,x='bathrooms',y='price',kind='box')

# %%
sns.pairplot(data=data,x_vars=['area','bedrooms','bathrooms'],y_vars=['price'],size=10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=data,x_vars=['stories','mainroad','guestroom'],y_vars=['price'],size=10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=data,x_vars=['basement','hotwaterheating','airconditioning'],y_vars=['price'],size=10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=data,x_vars=['parking','prefarea','furnishingstatus'],y_vars=['price'],size=10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Dividing the data

# %%
x=data[['area','bedrooms','stories','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea','furnishingstatus']]
y=data['price']

# %%
x.head()
# Out:
#    area  bedrooms  stories  mainroad  guestroom  basement  hotwaterheating  \
# 0  7420         4        3         1          0         0                0
# 1  8960         4        4         1          0         0                0
# 2  9960         3        2         1          0         1                0
# 3  7500         4        2         1          0         1                0
# 4  7420         4        2         1          1         1                0
#
#    airconditioning  parking  prefarea  furnishingstatus
# 0                1        2         1                 2
# 1                1        3         0                 2
# 2                0        2         1                 1
# 3                1        3         1                 2
# 4                1        2         0                 2

# %%
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %% [markdown]
# Spliting the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (436, 11)

# %%
y_train.shape
# Out:
# (436,)

# %%
x_test.shape
# Out:
# (109, 11)

# %%
y_test.shape
# Out:
# (109,)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=regression.predict(x_test)

# %%
predictions
# Out:
# array([5400647.98582362, 4459653.73291987, 6213552.70950943,
#        3006041.79423482, 4143923.31155238, 4525812.07141046,
#        6845062.53601606, 2541421.443615  , 6121811.49918484,
#        4873171.75619887, 6466221.42719363, 3218864.41535526,
#        2666673.47109413, 7820446.46395223, 6561221.47818142,
#        6152018.06348836, 7065137.28650501, 4155675.08302158,
#        5268926.91350412, 4073755.9503731 , 2782153.5502669 ,
#        5104338.4294675 , 2941529.48752005, 4426002.68259573,
#        4216812.12324002, 4679137.9608404 , 7601178.03303539,
#        4976675.18849043, 4485084.05850107, 5618472.3188972 ,
#        3717741.05873869, 2158821.32518199, 7196501.81976171,
#        5357996.37931363, 4657638.1050032 , 2541421.443615  ,
#        5992789.38700288, 3919035.31999407, 4387630.32183353,
#        3372055.22168676, 3182261.59417196, 4497219.16481395,
#        5211633.32341774, 4087969.00157413, 7968375.77922596,
#        8415610.59153423, 3397131.48279633, 5149789.98921321,
#        4474130.920873  , 4873171.75619887, 4775281.72609626,
#        9096202.50246241, 5236660.6708659 , 6055561.33165207,
#        2546947.30545631, 4729146.78022019, 5516086.60201407,
#        2796643.24000859, 6397209.35543812, 4892310.38757558,
#        2055683.0563218 , 6407420.67367584, 3870917.66376897,
#        3282521.75992481, 4493871.53474498, 4649810.44180315,
#        7526552.93905004, 4154221.71103079, 3130558.42569167,
#        6586232.59844021, 3395409.81360333, 3134644.98645242,
#        4017585.02615469, 4272701.60132265, 5064927.53328158,
#        4068464.05961053, 6201168.28794017, 5610397.20196324,
#        5632004.32486438, 4742487.88269468, 4370218.71796843,
#        6230337.16808743, 6574926.06301517, 5607186.49795423,
#        7027928.60276703, 3054473.95239048, 3964648.3386169 ,
#        8385118.16527699, 4058752.23456636, 3799781.49947793,
#        6324065.32267088, 3940174.21502595, 4665077.07156594,
#        5733097.84685639, 5253677.04306979, 2911994.04111263,
#        2748998.3439004 , 5429673.84933871, 3398952.8139348 ,
#        6026861.63034578, 3841287.80028659, 3557010.01855271,
#        3937132.36818493, 5093379.61131744, 4359702.7529532 ,
#        4442498.47322618, 6399817.22211378, 2700111.40869803,
#        4741501.19070861])

# %%
regression.score(x,y)
# Out:
# 0.6213678003443729

# %% [markdown]
# For a new customer, How Much should be the price of the house with different facilities

# %%
#new data
data_new={'area':8080,'bedrooms':4,'stories':3,'mainroad':1,'guestroom':1,'basement':1,'hotwaterheating':0,'airconditioning':1,'parking':3,'prefarea':1,'furnishingstatus':1}

# %%
index=[1]
my_data=pd.DataFrame(data_new,index)

# %%
my_data
# Out:
#    area  bedrooms  stories  mainroad  guestroom  basement  hotwaterheating  \
# 1  8080         4        3         1          1         1                0
#
#    airconditioning  parking  prefarea  furnishingstatus
# 1                1        3         1                 1

# %%
new_predictions=regression.predict(my_data)
print("The cost of the New house Will be",new_predictions)
# Out:
# The cost of the New house Will be [9193708.6691444]
